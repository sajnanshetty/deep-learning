# %%
from google.colab import drive
ROOT = "/content/gdrive"
drive.mount(ROOT, force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
import os
import time
import glob
import torch
import os
from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

#folder = '/content/gdrive/My Drive/Colab Notebooks/my_project1/deep-learning/utils'
folder = '/content/gdrive/My Drive/Colab Notebooks/my_project1/deep-learning/s13/YoloV3'
os.chdir(folder)
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !ls
# Out:
#  cfg	     output	    results.png   train.py	      weights
#  data	     __pycache__    runs	 'ubdivisions=1'      yolo_v3.ipynb
#  detect.py   README.md	    test.py	  utils
#  models.py   results.json   ting	  vim.exe.stackdump

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-04 10:51:40.169865: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (500 found, 0 missing, 0 empty, 0 duplicate, for 500 images): 100% 500/500 [03:40<00:00,  2.27it/s]
# Caching images (0.3GB): 100% 500/500 [04:10<00:00,  1.99it/s]
# ...

# %% [markdown]
# ### Video1 clipping detection

# %%
# !python detect.py --conf-thres 0.2 --source data/video_images --output video_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.2, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='video_out', save_txt=False, source='data/video_images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/120 data/video_images/image-431.png: 384x512 Done. (0.037s)
# image 2/120 data/video_images/image-432.png: 384x512 Done. (0.037s)
# image 3/120 data/video_images/image-433.png: 384x512 Done. (0.037s)
# image 4/120 data/video_images/image-434.png: 384x512 Done. (0.037s)
# image 5/120 data/video_images/image-435.png: 384x512 Done. (0.037s)
# image 6/120 data/video_images/image-436.png: 384x512 Done. (0.037s)
# image 7/120 data/video_images/image-437.png: 384x512 Done. (0.037s)
# ...

# %%
Image(filename='video_out/image-521.png', width=600)

# %% [markdown]
# ## Video2 clippings detection

# %%
# !python detect.py --conf-thres 0.2 --source video3_images --output video_out2
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.2, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='video_out2', save_txt=False, source='video3_images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/408 video3_images/image-1659.png: 320x512 1 jerrys, Done. (0.033s)
# image 2/408 video3_images/image-1660.png: 320x512 1 jerrys, Done. (0.033s)
# image 3/408 video3_images/image-1661.png: 320x512 1 jerrys, Done. (0.033s)
# image 4/408 video3_images/image-1662.png: 320x512 1 jerrys, Done. (0.033s)
# image 5/408 video3_images/image-1663.png: 320x512 1 jerrys, Done. (0.033s)
# image 6/408 video3_images/image-1664.png: 320x512 1 jerrys, Done. (0.033s)
# ...

# %%
Image(filename='video_out2/image-2032.png', width=600)

# %%
Image(filename='video_out2/image-1996.png', width=600)
